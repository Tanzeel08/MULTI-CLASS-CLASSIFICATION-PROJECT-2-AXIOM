# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanzeel08/MULTI-CLASS-CLASSIFICATION-PROJECT-2-AXIOM/blob/master/Untitled9(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1dfe9d0c-1ad8-4656-881d-019a266332ee" name="files[]" multiple disabled />
#      <output id="result-1dfe9d0c-1ad8-4656-881d-019a266332ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris (1).csv

# %%
# load dataset
dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

# %%
print(dataframe)
print(X)
print("***************************")
print(Y)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

# %% [markdown]
# # **definig the neural network bas line model**

# %%
#define base line 
def baseline_model():
    from keras import models
    from keras import layers
    model=models.Sequential()
    model.add(layers.Dense(39,activation='relu',input_shape=(4,)))
    model.add(layers.Dense(39,activation='relu')) 
    model.add(layers.Dense(3,activation='softmax'))
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
  
  
    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=0)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 97.33% (4.42%)

# %% [markdown]
# # Tuning Layers and Number of Neurons in The Model

# %% [markdown]
# # Evaluate a Smaller Network

# %%
def baseline_model():
    from keras import models
    from keras import layers
    model=models.Sequential()
    model.add(layers.Dense(36,activation='relu',input_shape=(4,)))
    model.add(layers.Dense(36,activation='relu')) 
    model.add(layers.Dense(3,activation='softmax'))
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
  
  
    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=0)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Smaller Network: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 96.67% (4.47%)

# %% [markdown]
# # EVALUATING LARGE NETWORK

# %%
def baseline_model():
    from keras import models
    from keras import layers
    model=models.Sequential()
    model.add(layers.Dense(512,activation='relu',input_shape=(4,)))
    model.add(layers.Dense(512,activation='relu')) 
    model.add(layers.Dense(3,activation='softmax'))
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
  
  
    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=0)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Larger Network: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/300
# 135/135 [==============================] - 6s 44ms/step - loss: 0.9493 - acc: 0.5481
# Epoch 2/300
# 135/135 [==============================] - 0s 510us/step - loss: 0.4895 - acc: 0.8000
# Epoch 3/300
# 135/135 [==============================] - 0s 478us/step - loss: 0.3837 - acc: 0.8444
# Epoch 4/300
# 135/135 [==============================] - 0s 480us/step - loss: 0.3871 - acc: 0.7852
# Epoch 5/300
# 135/135 [==============================] - 0s 498us/step - loss: 0.2448 - acc: 0.9185
# Epoch 6/300
# 135/135 [==============================] - 0s 506us/step - loss: 0.2732 - acc: 0.9111
# Epoch 7/300
# 135/135 [==============================] - 0s 414us/step - loss: 0.2318 - acc: 0.9037
# Epoch 8/300
# 135/135 [==============================] - 0s 421us/step - loss: 0.1632 - acc: 0.9704
# Epoch 9/300
# 135/135 [==============================] - 0s 451us/step - loss: 0.1825 - acc: 0.9037
# Epoch 10/300
# ...

# %% [markdown]
# # DEVELOPING A MODEL THAT OVERFITS

# %%
def baseline_model():
    from keras import models
    from keras import layers
    model=models.Sequential()
    model.add(layers.Dense(550,activation='relu',input_shape=(4,)))
    model.add(layers.Dense(550,activation='relu')) 
    model.add(layers.Dense(3,activation='softmax'))
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
  
  
    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=10, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("overfit: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/200
# 135/135 [==============================] - 5s 38ms/step - loss: 0.8327 - acc: 0.6370
# Epoch 2/200
# 135/135 [==============================] - 0s 725us/step - loss: 0.4757 - acc: 0.7852
# Epoch 3/200
# 135/135 [==============================] - 0s 711us/step - loss: 0.3921 - acc: 0.8000
# Epoch 4/200
# 135/135 [==============================] - 0s 719us/step - loss: 0.3703 - acc: 0.8222
# Epoch 5/200
# 135/135 [==============================] - 0s 686us/step - loss: 0.1865 - acc: 0.9481
# Epoch 6/200
# 135/135 [==============================] - 0s 704us/step - loss: 0.2742 - acc: 0.9037
# Epoch 7/200
# 135/135 [==============================] - 0s 654us/step - loss: 0.1675 - acc: 0.9407
# Epoch 8/200
# 135/135 [==============================] - 0s 667us/step - loss: 0.2182 - acc: 0.9111
# Epoch 9/200
# 135/135 [==============================] - 0s 698us/step - loss: 0.1076 - acc: 0.9630
# Epoch 10/200
# ...

# %% [markdown]
# # TUNING THE MODEL

# %%
def baseline_model():
    from keras import models
    from keras import layers
    model=models.Sequential()
    model.add(layers.Dense(350,activation='relu',input_shape=(4,)))
    model.add(layers.Dense(350,activation='relu')) 
    model.add(layers.Dense(3,activation='softmax'))
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
  
  
    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=300, batch_size=10, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("tuning: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/300
# 135/135 [==============================] - 5s 40ms/step - loss: 0.8254 - acc: 0.6444
# Epoch 2/300
# 135/135 [==============================] - 0s 417us/step - loss: 0.4230 - acc: 0.7926
# Epoch 3/300
# 135/135 [==============================] - 0s 370us/step - loss: 0.3879 - acc: 0.7926
# Epoch 4/300
# 135/135 [==============================] - 0s 397us/step - loss: 0.2697 - acc: 0.8963
# Epoch 5/300
# 135/135 [==============================] - 0s 400us/step - loss: 0.3198 - acc: 0.8370
# Epoch 6/300
# 135/135 [==============================] - 0s 393us/step - loss: 0.1863 - acc: 0.9630
# Epoch 7/300
# 135/135 [==============================] - 0s 397us/step - loss: 0.2672 - acc: 0.8889
# Epoch 8/300
# 135/135 [==============================] - 0s 392us/step - loss: 0.1951 - acc: 0.9037
# Epoch 9/300
# 135/135 [==============================] - 0s 429us/step - loss: 0.1619 - acc: 0.9407
# Epoch 10/300
# ...

# %% [markdown]
# # KERAS FUNCTIONAL API

# %%
#import keras
#from keras import layers
from keras.layers import Input, Dense
from keras.models import Model
inputs=keras.Input(shape=(4,))
x=layers.Dense(46,activation='relu')(inputs)
x=layers.Dense(46,activation='relu')(x)
outputs=layers.Dense(3,activation='softmax')(x)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy']) 
model=keras.Model(inputs,outputs)
print("functional API: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 94.00% (7.57%)

# %% [markdown]
# # RE WRITING A CODE USING SUB CLASSING

# %%
import keras
from keras import layers
class MyModel(keras.Model):
    def __init__(self):
        super(MyModel,self).__init__()
        self.dense1=layers.Dense(20,activation='relu')
        self.dense2=layers.Dense(20,activation='relu')
        self.dense3=layers.Dense(20,activation='relu')
    def call(self,inputs):
        x=self.dense1(x)
        x=self.dense2(x)
        return self.dense3(x)
model=MyModel()
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 94.00% (7.57%)

# %% [markdown]
# # RE WRITINT A CODE USING SCIKIT-LEARN

# %%
import numpy
import pandas
import keras
from keras import layers
from keras import models
model=models.Sequential()
model.add(layers.Dense(22,activation='relu',input_shape=(4,)))
model.add(layers.Dense(22,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 94.00% (7.57%)

# %%
numpy.size(dataframe)
# Out:
# 750
